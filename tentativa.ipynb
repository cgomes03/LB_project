# %%
from Bio import SeqIO, AlignIO, Phylo
from Bio.SeqRecord import SeqRecord
from Bio.Phylo.TreeConstruction import DistanceCalculator, DistanceTreeConstructor
import subprocess
import os
import matplotlib.pyplot as plt
import re

def process_gene_with_clustal(gene_name, fasta_file):
    # Create output directory
    output_dir = "filogenetic_analysis"
    os.makedirs(output_dir, exist_ok=True)

    # Read the FASTA file
    sequences = []
    with open(fasta_file) as handle:
        for record in SeqIO.parse(handle, "fasta"):
            sequences.append(record)

    # Save the extracted sequences in a FASTA file
    trimmed_fasta = os.path.join(output_dir, f"{gene_name}_trimmed.fasta")
    SeqIO.write(sequences, trimmed_fasta, "fasta")

    # Path to the ClustalW2 executable
    clustal_exe = "clustalw2"  # Replace with the correct executable path if necessary

    # Define the alignment output file
    alignment_file = os.path.join(output_dir, f"{gene_name}_alignment.fasta")

    # Execute the ClustalW2 command to perform the alignment
    clustal_command = [
        clustal_exe,
        f"/INFILE={trimmed_fasta}",
        f"/OUTFILE={alignment_file}",
        "/OUTPUT=FASTA",
        "/QUIET"
    ]

    print(f"Running ClustalW2 for gene {gene_name}...")
    try:
        subprocess.run(clustal_command, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error executing ClustalW2: {e}")
        return

    # Check if the alignment was successfully generated
    if not os.path.exists(alignment_file):
        raise FileNotFoundError(f"Alignment was not generated for gene {gene_name}.")

    # Read the generated alignment
    alignment = AlignIO.read(alignment_file, "fasta")

    # Ensure unique IDs and preserve important information
    unique_ids = set()
    query_id = None  # Para armazenar a identificação da query, se necessário

    for record in alignment:
        original_id = record.id
        full_description = record.description

        # Tenta extrair o nome da espécie da descrição, se disponível
        species_match = re.search(r"\[(.*?)\]", full_description)
        if species_match:
            full_id = species_match.group(1).replace(" ", "_")  # Usa o nome da espécie
        else:
            full_id = original_id  # Caso contrário, mantém o ID original

        # Se a sequência corresponde à tua query, guarda a referência
        if "query" in full_description.lower() or "query" in original_id.lower():
            query_id = full_id

        # Evitar duplicados
        if full_id in unique_ids:
            print(f"Duplicate ID found: {full_id}. Skipping...")
            continue

        # Atualizar ID da sequência
        record.id = full_id
        record.description = full_id
        unique_ids.add(full_id)

    # Verifica se a query foi encontrada
    if query_id:
        print(f"Query identificada: {query_id}")
    else:
        print("Aviso: A query não foi identificada no alinhamento.")


    # Compute distance matrix
    calculator = DistanceCalculator('blosum62')
    try:
        dm = calculator.get_distance(alignment)
        print(f"Distance Matrix:\n{dm}")
    except ValueError as e:
        print(f"Error calculating distance matrix: {e}")
        return

    # Build trees
    constructor = DistanceTreeConstructor()
    upgma_tree = constructor.upgma(dm)
    nj_tree = constructor.nj(dm)

    # Destacar a query e remover 'Inner' labels
    for tree in [upgma_tree, nj_tree]:
        for clade in tree.find_clades():
            if 'Inner' in (clade.name or ''):
                clade.name = ""
            if clade.name == query_id:
                clade.color = 'red'  # Destaca a query a vermelho
                clade.name = f'*** QUERY: {clade.name} ***'
            elif 'Homo' in (clade.name or ''):
                clade.color = 'orange'
                clade.name = f'*** {clade.name} ***'

    # Save trees
    Phylo.write(upgma_tree, os.path.join(output_dir, f'{gene_name}_upgma_tree.nwk'), 'newick')
    Phylo.write(nj_tree, os.path.join(output_dir, f'{gene_name}_nj_tree.nwk'), 'newick')

    # Process and plot trees
    for tree, tree_type in [(upgma_tree, 'UPGMA'), (nj_tree, 'NJ')]:
        # Create figure and axes
        fig = plt.figure(figsize=(35, 15))  # Increase figure size
        ax = fig.add_subplot(1, 1, 1)

        # Draw tree on created axes
        Phylo.draw(tree, do_show=False, axes=ax)
        for label in ax.get_xticklabels() + ax.get_yticklabels():
            label.set_fontsize(18)
        for text in ax.findobj(match=plt.Text):  # Find all text objects
            text.set_fontsize(22)

        # Add title
        plt.title(f'{gene_name} - {tree_type} Tree', fontsize=30)

        # Save tree image
        tree_img = os.path.join(output_dir, f'{gene_name}_{tree_type}_tree.png')
        plt.savefig(tree_img, bbox_inches='tight')  # 'bbox_inches' ensures nothing gets cut off
        plt.close()

    print(f"Processing completed for gene {gene_name}. Results saved in '{output_dir}'.")

# %%
from Bio import SeqIO, AlignIO, Phylo
from Bio.Phylo.TreeConstruction import DistanceCalculator, DistanceTreeConstructor
import subprocess
import os
import matplotlib.pyplot as plt
import re

def find_query(query_name, query_dir="genes"):
    """Procura o ficheiro da query na pasta especificada."""
    query_path = os.path.join(query_dir, f"{query_name}.fasta")
    if os.path.exists(query_path):
        return query_path
    else:
        raise FileNotFoundError(f"Query {query_name} não encontrada em {query_dir}.")

def process_gene_with_clustal(gene_name, fasta_file, query_name):
    output_dir = "filogenetic_analysis"
    os.makedirs(output_dir, exist_ok=True)

    # Encontrar a query
    query_path = find_query(query_name)

    # Ler a query
    query_record = next(SeqIO.parse(query_path, "fasta"))
    query_id = query_record.id

    # Ler as sequências do FASTA e filtrar por nome de espécie
    sequences = []
    species_seen = set()

    with open(fasta_file) as handle:
        for record in SeqIO.parse(handle, "fasta"):
            species_match = re.search(r"\[(.*?)\]", record.description)
            if species_match:
                species_name = species_match.group(1).replace(" ", "_")
            else:
                species_name = record.id  # Fallback para ID caso não haja nome da espécie

            if species_name not in species_seen:
                species_seen.add(species_name)
                record.id = species_name  # Atualizar ID para o nome da espécie
                record.description = species_name
                sequences.append(record)

    # Se houver mais de 10 sequências, escolher as 10 maiores
    if len(sequences) > 10:
        sequences = sorted(sequences, key=lambda x: len(x.seq), reverse=True)[:10]

    # Adicionar a query à lista
    sequences.insert(0, query_record)

    # Guardar as sequências filtradas
    trimmed_fasta = os.path.join(output_dir, f"{gene_name}_trimmed.fasta")
    SeqIO.write(sequences, trimmed_fasta, "fasta")

    # Caminho do ClustalW2
    clustal_exe = "clustalw2"

    # Definir ficheiro de saída do alinhamento
    alignment_file = os.path.join(output_dir, f"{gene_name}_alignment.fasta")

    # Executar ClustalW2 para alinhamento
    clustal_command = [
        clustal_exe,
        f"/INFILE={trimmed_fasta}",
        f"/OUTFILE={alignment_file}",
        "/OUTPUT=FASTA",
        "/QUIET"
    ]

    print(f"Running ClustalW2 for gene {gene_name}...")
    try:
        subprocess.run(clustal_command, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error executing ClustalW2: {e}")
        return

    # Verificar se o alinhamento foi gerado
    if not os.path.exists(alignment_file):
        raise FileNotFoundError(f"Alignment was not generated for gene {gene_name}.")

    # Ler o alinhamento gerado
    alignment = AlignIO.read(alignment_file, "fasta")

    # Calcular a matriz de distâncias
    calculator = DistanceCalculator('blosum62')
    try:
        dm = calculator.get_distance(alignment)
    except ValueError as e:
        print(f"Error calculating distance matrix: {e}")
        return

    # Construir árvores filogenéticas
    constructor = DistanceTreeConstructor()
    upgma_tree = constructor.upgma(dm)
    nj_tree = constructor.nj(dm)

    # Destacar a query e formatar nomes
    for tree in [upgma_tree, nj_tree]:
        for clade in tree.find_clades():
            if clade.name == query_id:
                clade.color = 'red'
                clade.name = f'*** QUERY: {clade.name} ***'

    # Guardar árvores
    Phylo.write(upgma_tree, os.path.join(output_dir, f"{gene_name}_upgma_tree.nwk"), "newick")
    Phylo.write(nj_tree, os.path.join(output_dir, f"{gene_name}_nj_tree.nwk"), "newick")

    # Gerar imagens das árvores
    for tree, tree_type in [(upgma_tree, "UPGMA"), (nj_tree, "NJ")]:
        fig = plt.figure(figsize=(35, 15))
        ax = fig.add_subplot(1, 1, 1)
        Phylo.draw(tree, do_show=False, axes=ax)
        plt.title(f"{gene_name} - {tree_type} Tree", fontsize=30)
        plt.savefig(os.path.join(output_dir, f"{gene_name}_{tree_type}_tree.png"), bbox_inches="tight")
        plt.close()

    print(f"Processing completed for gene {gene_name}. Results saved in '{output_dir}'.")

# %%
from Bio import SeqIO, AlignIO, Phylo
from Bio.Phylo.TreeConstruction import DistanceCalculator, DistanceTreeConstructor
import subprocess
import os
import matplotlib.pyplot as plt
import re

def process_gene_with_clustal(gene_name):
    # Definir diretórios
    genes_dir = "genes"
    blast_results_dir = "blast_results"
    output_dir = "filogenetic_analysis"
    os.makedirs(output_dir, exist_ok=True)

    # Buscar a query principal na pasta 'genes'
    query_path = os.path.join(genes_dir, f"{gene_name}.fasta")
    if not os.path.exists(query_path):
        raise FileNotFoundError(f"Query file not found: {query_path}")
    
    query_seq = next(SeqIO.parse(query_path, "fasta"))  # Assume apenas uma query

    # Buscar sequências do BLAST na pasta 'blast_results'
    blast_fasta = os.path.join(blast_results_dir, f"{gene_name}_blast.fasta")
    if not os.path.exists(blast_fasta):
        raise FileNotFoundError(f"BLAST results file not found: {blast_fasta}")

    # Filtrar sequências com nomes de espécies diferentes
    unique_species = {}
    with open(blast_fasta) as handle:
        for record in SeqIO.parse(handle, "fasta"):
            species_match = re.search(r"\[(.*?)\]", record.description)
            if species_match:
                species_name = species_match.group(1).replace(" ", "_")
                if species_name not in unique_species:
                    unique_species[species_name] = record
    
    # Selecionar até 10 melhores sequências
    selected_seqs = list(unique_species.values())[:10]
    selected_seqs.insert(0, query_seq)  # Garantir que a query está incluída

    print(f"Query: {query_seq.id} - {query_seq.description}")

    print(f"Ficheiro BLAST encontrado? {os.path.exists(blast_fasta)}")
    if os.path.exists(blast_fasta):
        print(f"Tamanho do ficheiro BLAST: {os.path.getsize(blast_fasta)} bytes")

    print("Sequências extraídas do BLAST:")
    unique_species = {}
    with open(blast_fasta) as handle:
        for record in SeqIO.parse(handle, "fasta"):
            print(f"Encontrado: {record.id} - {record.description}")  # Debug

            species_match = re.search(r"\[(.*?)\]", record.description)
            if species_match:
                species_name = species_match.group(1).replace(" ", "_")
                print(f"  -> Nome da espécie extraído: {species_name}")
                if species_name not in unique_species:
                    unique_species[species_name] = record
            else:
                print(f"  -> Aviso: Não foi possível extrair nome da espécie de {record.description}")

    print(f"Total de espécies únicas: {len(unique_species)}")



    # Guardar no ficheiro trimmed
    trimmed_fasta = os.path.join(output_dir, f"{gene_name}_trimmed.fasta")
    SeqIO.write(selected_seqs, trimmed_fasta, "fasta")

    # Executar ClustalW2 para alinhamento
    clustal_exe = "clustalw2"
    alignment_file = os.path.join(output_dir, f"{gene_name}_alignment.fasta")
    clustal_command = [
        clustal_exe,
        f"/INFILE={trimmed_fasta}",
        f"/OUTFILE={alignment_file}",
        "/OUTPUT=FASTA",
        "/QUIET"
    ]
    subprocess.run(clustal_command, check=True)

    # Ler alinhamento
    alignment = AlignIO.read(alignment_file, "fasta")
    
    # Calcular matriz de distâncias
    calculator = DistanceCalculator('blosum62')
    dm = calculator.get_distance(alignment)

    # Construir árvores
    constructor = DistanceTreeConstructor()
    upgma_tree = constructor.upgma(dm)
    nj_tree = constructor.nj(dm)
    
    # Destacar a query na árvore
    for tree in [upgma_tree, nj_tree]:
        for clade in tree.find_clades():
            if clade.name == query_seq.id:
                clade.color = 'red'
                clade.name = f'*** QUERY: {clade.name} ***'
    
    # Guardar árvores
    Phylo.write(upgma_tree, os.path.join(output_dir, f'{gene_name}_upgma_tree.nwk'), 'newick')
    Phylo.write(nj_tree, os.path.join(output_dir, f'{gene_name}_nj_tree.nwk'), 'newick')
    
    # Plotar árvores
    for tree, tree_type in [(upgma_tree, 'UPGMA'), (nj_tree, 'NJ')]:
        fig = plt.figure(figsize=(35, 15))
        ax = fig.add_subplot(1, 1, 1)
        Phylo.draw(tree, do_show=False, axes=ax)
        plt.title(f'{gene_name} - {tree_type} Tree', fontsize=30)
        plt.savefig(os.path.join(output_dir, f'{gene_name}_{tree_type}_tree.png'), bbox_inches='tight')
        plt.close()
    
    print(f"Processing completed for gene {gene_name}. Results saved in '{output_dir}'.")

# %%
process_gene_with_clustal("ptsP")
# Out:
# Query: WP_005925321.1 - WP_005925321.1 phosphoenolpyruvate--protein phosphotransferase [Faecalibacterium prausnitzii]
# Ficheiro BLAST encontrado? True
# Tamanho do ficheiro BLAST: 31203 bytes
# Sequências extraídas do BLAST:
# Encontrado: Q9K8D3 - Q9K8D3 E-value: 5.96e-160, Identities: 228/530, Query Cover: 96.89%, Percent Identity: 43.02%, Species: Halalkalibacterium halodurans C-125
#   -> Aviso: Não foi possível extrair nome da espécie de Q9K8D3 E-value: 5.96e-160, Identities: 228/530, Query Cover: 96.89%, Percent Identity: 43.02%, Species: Halalkalibacterium halodurans C-125
# Encontrado: O83018 - O83018 E-value: 4.76e-154, Identities: 235/530, Query Cover: 96.89%, Percent Identity: 44.34%, Species: Bacillus sp. S
#   -> Aviso: Não foi possível extrair nome da espécie de O83018 E-value: 4.76e-154, Identities: 235/530, Query Cover: 96.89%, Percent Identity: 44.34%, Species: Bacillus sp. S
# Encontrado: P42014 - P42014 E-value: 6.92e-153, Identities: 235/530, Query Cover: 96.89%, Percent Identity: 44.34%, Species: Geobacillus stearothermophilus
#   -> Aviso: Não foi possível extrair nome da espécie de P42014 E-value: 6.92e-153, Identities: 235/530, Query Cover: 96.89%, Percent Identity: 44.34%, Species: Geobacillus stearothermophilus
# Encontrado: O69251 - O69251 E-value: 2.70e-150, Identities: 227/536, Query Cover: 97.99%, Percent Identity: 42.35%, Species: Priestia megaterium
#   -> Aviso: Não foi possível extrair nome da espécie de O69251 E-value: 2.70e-150, Identities: 227/536, Query Cover: 97.99%, Percent Identity: 42.35%, Species: Priestia megaterium
# Encontrado: P08838 - P08838 E-value: 3.80e-149, Identities: 228/541, Query Cover: 98.90%, Percent Identity: 42.14%, Species: Bacillus subtilis subsp. subtilis str. 168
#   -> Aviso: Não foi possível extrair nome da espécie de P08838 E-value: 3.80e-149, Identities: 228/541, Query Cover: 98.90%, Percent Identity: 42.14%, Species: Bacillus subtilis subsp. subtilis str. 168
# Encontrado: P23530 - P23530 E-value: 2.50e-145, Identities: 232/548, Query Cover: 100.18%, Percent Identity: 42.34%, Species: Enterococcus faecalis V583
#   -> Aviso: Não foi possível extrair nome da espécie de P23530 E-value: 2.50e-145, Identities: 232/548, Query Cover: 100.18%, Percent Identity: 42.34%, Species: Enterococcus faecalis V583
# Encontrado: P23533 - P23533 E-value: 9.58e-145, Identities: 217/543, Query Cover: 99.27%, Percent Identity: 39.96%, Species: Staphylococcus carnosus subsp. carnosus TM300
#   -> Aviso: Não foi possível extrair nome da espécie de P23533 E-value: 9.58e-145, Identities: 217/543, Query Cover: 99.27%, Percent Identity: 39.96%, Species: Staphylococcus carnosus subsp. carnosus TM300
# Encontrado: Q9WXK9 - Q9WXK9 E-value: 6.55e-144, Identities: 229/549, Query Cover: 100.37%, Percent Identity: 41.71%, Species: Streptococcus equinus
#   -> Aviso: Não foi possível extrair nome da espécie de Q9WXK9 E-value: 6.55e-144, Identities: 229/549, Query Cover: 100.37%, Percent Identity: 41.71%, Species: Streptococcus equinus
# Encontrado: Q92D19 - Q92D19 E-value: 6.73e-144, Identities: 217/540, Query Cover: 98.72%, Percent Identity: 40.19%, Species: Listeria innocua Clip11262
#   -> Aviso: Não foi possível extrair nome da espécie de Q92D19 E-value: 6.73e-144, Identities: 217/540, Query Cover: 98.72%, Percent Identity: 40.19%, Species: Listeria innocua Clip11262
# Encontrado: O31149 - O31149 E-value: 1.60e-143, Identities: 217/540, Query Cover: 98.72%, Percent Identity: 40.19%, Species: Listeria monocytogenes EGD-e
#   -> Aviso: Não foi possível extrair nome da espécie de O31149 E-value: 1.60e-143, Identities: 217/540, Query Cover: 98.72%, Percent Identity: 40.19%, Species: Listeria monocytogenes EGD-e
# Encontrado: O07126 - O07126 E-value: 5.67e-143, Identities: 224/541, Query Cover: 98.90%, Percent Identity: 41.40%, Species: Latilactobacillus sakei
#   -> Aviso: Não foi possível extrair nome da espécie de O07126 E-value: 5.67e-143, Identities: 224/541, Query Cover: 98.90%, Percent Identity: 41.40%, Species: Latilactobacillus sakei
# Encontrado: P30299 - P30299 E-value: 1.23e-142, Identities: 231/549, Query Cover: 100.37%, Percent Identity: 42.08%, Species: Streptococcus salivarius
#   -> Aviso: Não foi possível extrair nome da espécie de P30299 E-value: 1.23e-142, Identities: 231/549, Query Cover: 100.37%, Percent Identity: 42.08%, Species: Streptococcus salivarius
# Encontrado: P45595 - P45595 E-value: 7.91e-142, Identities: 227/549, Query Cover: 100.37%, Percent Identity: 41.35%, Species: Streptococcus mutans UA159
#   -> Aviso: Não foi possível extrair nome da espécie de P45595 E-value: 7.91e-142, Identities: 227/549, Query Cover: 100.37%, Percent Identity: 41.35%, Species: Streptococcus mutans UA159
# Encontrado: P43922 - P43922 E-value: 8.39e-141, Identities: 228/535, Query Cover: 97.81%, Percent Identity: 42.62%, Species: Haemophilus influenzae Rd KW20
#   -> Aviso: Não foi possível extrair nome da espécie de P43922 E-value: 8.39e-141, Identities: 228/535, Query Cover: 97.81%, Percent Identity: 42.62%, Species: Haemophilus influenzae Rd KW20
# Encontrado: Q9CJ82 - Q9CJ82 E-value: 5.51e-140, Identities: 226/545, Query Cover: 99.63%, Percent Identity: 41.47%, Species: Lactococcus lactis subsp. lactis Il1403
#   -> Aviso: Não foi possível extrair nome da espécie de Q9CJ82 E-value: 5.51e-140, Identities: 226/545, Query Cover: 99.63%, Percent Identity: 41.47%, Species: Lactococcus lactis subsp. lactis Il1403
# Encontrado: Q5HQ85 - Q5HQ85 E-value: 9.30e-140, Identities: 220/549, Query Cover: 100.37%, Percent Identity: 40.07%, Species: Staphylococcus epidermidis RP62A
#   -> Aviso: Não foi possível extrair nome da espécie de Q5HQ85 E-value: 9.30e-140, Identities: 220/549, Query Cover: 100.37%, Percent Identity: 40.07%, Species: Staphylococcus epidermidis RP62A
# Encontrado: Q9ZAD8 - Q9ZAD8 E-value: 1.20e-139, Identities: 225/545, Query Cover: 99.63%, Percent Identity: 41.28%, Species: Lactococcus cremoris
#   -> Aviso: Não foi possível extrair nome da espécie de Q9ZAD8 E-value: 1.20e-139, Identities: 225/545, Query Cover: 99.63%, Percent Identity: 41.28%, Species: Lactococcus cremoris
# Encontrado: Q84F83 - Q84F83 E-value: 1.90e-139, Identities: 215/536, Query Cover: 97.99%, Percent Identity: 40.11%, Species: Lysinibacillus sphaericus
#   -> Aviso: Não foi possível extrair nome da espécie de Q84F83 E-value: 1.90e-139, Identities: 215/536, Query Cover: 97.99%, Percent Identity: 40.11%, Species: Lysinibacillus sphaericus
# Encontrado: P51183 - P51183 E-value: 7.50e-139, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus
#   -> Aviso: Não foi possível extrair nome da espécie de P51183 E-value: 7.50e-139, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus
# Encontrado: Q6GAD0 - Q6GAD0 E-value: 1.60e-138, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus subsp. aureus MSSA476
#   -> Aviso: Não foi possível extrair nome da espécie de Q6GAD0 E-value: 1.60e-138, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus subsp. aureus MSSA476
# Encontrado: Q6GI01 - Q6GI01 E-value: 2.38e-138, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus subsp. aureus MRSA252
#   -> Aviso: Não foi possível extrair nome da espécie de Q6GI01 E-value: 2.38e-138, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus subsp. aureus MRSA252
# Encontrado: Q99V14 - Q99V14 E-value: 1.14e-137, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus subsp. aureus N315
#   -> Aviso: Não foi possível extrair nome da espécie de Q99V14 E-value: 1.14e-137, Identities: 217/546, Query Cover: 99.82%, Percent Identity: 39.74%, Species: Staphylococcus aureus subsp. aureus N315
# Encontrado: P45617 - P45617 E-value: 2.16e-137, Identities: 210/537, Query Cover: 98.17%, Percent Identity: 39.11%, Species: Mycoplasma capricolum subsp. capricolum ATCC 27343
#   -> Aviso: Não foi possível extrair nome da espécie de P45617 E-value: 2.16e-137, Identities: 210/537, Query Cover: 98.17%, Percent Identity: 39.11%, Species: Mycoplasma capricolum subsp. capricolum ATCC 27343
# Encontrado: Q931U2 - Q931U2 E-value: 5.20e-137, Identities: 216/546, Query Cover: 99.82%, Percent Identity: 39.56%, Species: Staphylococcus aureus subsp. aureus Mu50
#   -> Aviso: Não foi possível extrair nome da espécie de Q931U2 E-value: 5.20e-137, Identities: 216/546, Query Cover: 99.82%, Percent Identity: 39.56%, Species: Staphylococcus aureus subsp. aureus Mu50
# Encontrado: P0A249 - P0A249 E-value: 4.79e-136, Identities: 229/535, Query Cover: 97.81%, Percent Identity: 42.80%, Species: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
#   -> Aviso: Não foi possível extrair nome da espécie de P0A249 E-value: 4.79e-136, Identities: 229/535, Query Cover: 97.81%, Percent Identity: 42.80%, Species: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
# Encontrado: P08839 - P08839 E-value: 1.29e-133, Identities: 225/539, Query Cover: 98.54%, Percent Identity: 41.74%, Species: Escherichia coli K-12
#   -> Aviso: Não foi possível extrair nome da espécie de P08839 E-value: 1.29e-133, Identities: 225/539, Query Cover: 98.54%, Percent Identity: 41.74%, Species: Escherichia coli K-12
# Encontrado: Q8KA50 - Q8KA50 E-value: 4.35e-128, Identities: 205/540, Query Cover: 98.72%, Percent Identity: 37.96%, Species: Buchnera aphidicola str. Sg (Schizaphis graminum)
#   -> Aviso: Não foi possível extrair nome da espécie de Q8KA50 E-value: 4.35e-128, Identities: 205/540, Query Cover: 98.72%, Percent Identity: 37.96%, Species: Buchnera aphidicola str. Sg (Schizaphis graminum)
# Encontrado: Q89B04 - Q89B04 E-value: 2.22e-123, Identities: 199/543, Query Cover: 99.27%, Percent Identity: 36.65%, Species: Buchnera aphidicola str. Bp (Baizongia pistaciae)
#   -> Aviso: Não foi possível extrair nome da espécie de Q89B04 E-value: 2.22e-123, Identities: 199/543, Query Cover: 99.27%, Percent Identity: 36.65%, Species: Buchnera aphidicola str. Bp (Baizongia pistaciae)
# Encontrado: Q9WXI6 - Q9WXI6 E-value: 6.08e-122, Identities: 202/534, Query Cover: 97.62%, Percent Identity: 37.83%, Species: Buchnera aphidicola str. APS (Acyrthosiphon pisum)
#   -> Aviso: Não foi possível extrair nome da espécie de Q9WXI6 E-value: 6.08e-122, Identities: 202/534, Query Cover: 97.62%, Percent Identity: 37.83%, Species: Buchnera aphidicola str. APS (Acyrthosiphon pisum)
# Encontrado: P75168 - P75168 E-value: 9.35e-121, Identities: 208/546, Query Cover: 99.82%, Percent Identity: 38.10%, Species: Mycoplasmoides pneumoniae M129
#   -> Aviso: Não foi possível extrair nome da espécie de P75168 E-value: 9.35e-121, Identities: 208/546, Query Cover: 99.82%, Percent Identity: 38.10%, Species: Mycoplasmoides pneumoniae M129
# Encontrado: P47668 - P47668 E-value: 8.59e-118, Identities: 205/545, Query Cover: 99.63%, Percent Identity: 37.61%, Species: Mycoplasmoides genitalium G37
#   -> Aviso: Não foi possível extrair nome da espécie de P47668 E-value: 8.59e-118, Identities: 205/545, Query Cover: 99.63%, Percent Identity: 37.61%, Species: Mycoplasmoides genitalium G37
# Encontrado: O51508 - O51508 E-value: 1.70e-110, Identities: 199/551, Query Cover: 100.73%, Percent Identity: 36.12%, Species: Borreliella burgdorferi B31
#   -> Aviso: Não foi possível extrair nome da espécie de O51508 E-value: 1.70e-110, Identities: 199/551, Query Cover: 100.73%, Percent Identity: 36.12%, Species: Borreliella burgdorferi B31
# Encontrado: P23388 - P23388 E-value: 5.95e-100, Identities: 192/519, Query Cover: 94.88%, Percent Identity: 36.99%, Species: Rhodobacter capsulatus
#   -> Aviso: Não foi possível extrair nome da espécie de P23388 E-value: 5.95e-100, Identities: 192/519, Query Cover: 94.88%, Percent Identity: 36.99%, Species: Rhodobacter capsulatus
# Encontrado: D4GYE2 - D4GYE2 E-value: 4.87e-99, Identities: 213/546, Query Cover: 99.82%, Percent Identity: 39.01%, Species: Haloferax volcanii DS2
#   -> Aviso: Não foi possível extrair nome da espécie de D4GYE2 E-value: 4.87e-99, Identities: 213/546, Query Cover: 99.82%, Percent Identity: 39.01%, Species: Haloferax volcanii DS2
# Encontrado: P23536 - P23536 E-value: 2.37e-98, Identities: 185/493, Query Cover: 90.13%, Percent Identity: 37.53%, Species: Cupriavidus necator H16
#   -> Aviso: Não foi possível extrair nome da espécie de P23536 E-value: 2.37e-98, Identities: 185/493, Query Cover: 90.13%, Percent Identity: 37.53%, Species: Cupriavidus necator H16
# Encontrado: P32670 - P32670 E-value: 1.54e-95, Identities: 194/538, Query Cover: 98.35%, Percent Identity: 36.06%, Species: Escherichia coli K-12
#   -> Aviso: Não foi possível extrair nome da espécie de P32670 E-value: 1.54e-95, Identities: 194/538, Query Cover: 98.35%, Percent Identity: 36.06%, Species: Escherichia coli K-12
# Encontrado: Q83QP3 - Q83QP3 E-value: 1.59e-95, Identities: 184/539, Query Cover: 98.54%, Percent Identity: 34.14%, Species: Shigella flexneri
#   -> Aviso: Não foi possível extrair nome da espécie de Q83QP3 E-value: 1.59e-95, Identities: 184/539, Query Cover: 98.54%, Percent Identity: 34.14%, Species: Shigella flexneri
# Encontrado: P77439 - P77439 E-value: 1.98e-94, Identities: 183/539, Query Cover: 98.54%, Percent Identity: 33.95%, Species: Escherichia coli K-12
#   -> Aviso: Não foi possível extrair nome da espécie de P77439 E-value: 1.98e-94, Identities: 183/539, Query Cover: 98.54%, Percent Identity: 33.95%, Species: Escherichia coli K-12
# Encontrado: Q8FFD8 - Q8FFD8 E-value: 3.14e-94, Identities: 185/539, Query Cover: 98.54%, Percent Identity: 34.32%, Species: Escherichia coli CFT073
#   -> Aviso: Não foi possível extrair nome da espécie de Q8FFD8 E-value: 3.14e-94, Identities: 185/539, Query Cover: 98.54%, Percent Identity: 34.32%, Species: Escherichia coli CFT073
# Encontrado: Q8XBQ8 - Q8XBQ8 E-value: 4.13e-94, Identities: 183/539, Query Cover: 98.54%, Percent Identity: 33.95%, Species: Escherichia coli O157:H7
#   -> Aviso: Não foi possível extrair nome da espécie de Q8XBQ8 E-value: 4.13e-94, Identities: 183/539, Query Cover: 98.54%, Percent Identity: 33.95%, Species: Escherichia coli O157:H7
# Encontrado: P45597 - P45597 E-value: 1.21e-88, Identities: 202/553, Query Cover: 101.10%, Percent Identity: 36.53%, Species: Xanthomonas campestris pv. campestris str. ATCC 33913
#   -> Aviso: Não foi possível extrair nome da espécie de P45597 E-value: 1.21e-88, Identities: 202/553, Query Cover: 101.10%, Percent Identity: 36.53%, Species: Xanthomonas campestris pv. campestris str. ATCC 33913
# Encontrado: Q9KZP1 - Q9KZP1 E-value: 1.55e-86, Identities: 191/545, Query Cover: 99.63%, Percent Identity: 35.05%, Species: Streptomyces coelicolor A3(2)
#   -> Aviso: Não foi possível extrair nome da espécie de Q9KZP1 E-value: 1.55e-86, Identities: 191/545, Query Cover: 99.63%, Percent Identity: 35.05%, Species: Streptomyces coelicolor A3(2)
# Encontrado: P37177 - P37177 E-value: 2.35e-85, Identities: 170/521, Query Cover: 95.25%, Percent Identity: 32.63%, Species: Escherichia coli K-12
#   -> Aviso: Não foi possível extrair nome da espécie de P37177 E-value: 2.35e-85, Identities: 170/521, Query Cover: 95.25%, Percent Identity: 32.63%, Species: Escherichia coli K-12
# Encontrado: P37178 - P37178 E-value: 2.77e-84, Identities: 171/523, Query Cover: 95.61%, Percent Identity: 32.70%, Species: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
#   -> Aviso: Não foi possível extrair nome da espécie de P37178 E-value: 2.77e-84, Identities: 171/523, Query Cover: 95.61%, Percent Identity: 32.70%, Species: Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
# Encontrado: O29548 - O29548 E-value: 2.72e-47, Identities: 117/381, Query Cover: 69.65%, Percent Identity: 30.71%, Species: Archaeoglobus fulgidus DSM 4304
#   -> Aviso: Não foi possível extrair nome da espécie de O29548 E-value: 2.72e-47, Identities: 117/381, Query Cover: 69.65%, Percent Identity: 30.71%, Species: Archaeoglobus fulgidus DSM 4304
# Total de espécies únicas: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 process_gene_with_clustal("ptsP")
#
# Cell In[9], line 83, in process_gene_with_clustal(gene_name)
#      80 subprocess.run(clustal_command, check=True)
#      82 # Ler alinhamento
# ---> 83 alignment = AlignIO.read(alignment_file, "fasta")
#      85 # Calcular matriz de distâncias
#      86 calculator = DistanceCalculator('blosum62')
#
# File c:\Users\catar\anaconda3\envs\bio_env\lib\site-packages\Bio\AlignIO\__init__.py:386, in read(handle, format, seq_count)
#     384     alignment = next(iterator)
#     385 except StopIteration:
# --> 386     raise ValueError("No records found in handle") from None
#     387 try:
#     388     next(iterator)
#
# ValueError: No records found in handle
